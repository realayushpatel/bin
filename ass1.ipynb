# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_Facebook.csv',delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('dataset_Facebook.csv',delimiter=';')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_Facebook.csv',delimiter=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
subset1= df[['like','share','Category']]
subset1
# Out:
#        like  share  Category
# 0      79.0   17.0         2
# 1     130.0   29.0         2
# 2      66.0   14.0         3
# 3    1572.0  147.0         2
# 4     325.0   49.0         2
# ..      ...    ...       ...
# 495    53.0   26.0         3
# 496    53.0   22.0         2
# 497    93.0   18.0         1
# 498    91.0   38.0         3
# 499    91.0   28.0         2
#
# [500 rows x 3 columns]

# %%
subset2=df[['comment','Total Interactions','Paid','like']]
subset2
# Out:
#      comment  Total Interactions  Paid    like
# 0          4                 100   0.0    79.0
# 1          5                 164   0.0   130.0
# 2          0                  80   0.0    66.0
# 3         58                1777   1.0  1572.0
# 4         19                 393   0.0   325.0
# ..       ...                 ...   ...     ...
# 495        5                  84   0.0    53.0
# 496        0                  75   0.0    53.0
# 497        4                 115   0.0    93.0
# 498        7                 136   0.0    91.0
# 499        0                 119   NaN    91.0
#
# [500 rows x 4 columns]

# %%
concat=pd.concat([subset1,subset2])
concat
# Out:
#        like  share  Category  comment  Total Interactions  Paid
# 0      79.0   17.0       2.0      NaN                 NaN   NaN
# 1     130.0   29.0       2.0      NaN                 NaN   NaN
# 2      66.0   14.0       3.0      NaN                 NaN   NaN
# 3    1572.0  147.0       2.0      NaN                 NaN   NaN
# 4     325.0   49.0       2.0      NaN                 NaN   NaN
# ..      ...    ...       ...      ...                 ...   ...
# 495    53.0    NaN       NaN      5.0                84.0   0.0
# 496    53.0    NaN       NaN      0.0                75.0   0.0
# 497    93.0    NaN       NaN      4.0               115.0   0.0
# 498    91.0    NaN       NaN      7.0               136.0   0.0
# 499    91.0    NaN       NaN      0.0               119.0   NaN
#
# [1000 rows x 6 columns]

# %%
concat.sort_values(by=['comment'],ascending=False)
# Out:
#        like  share  Category  comment  Total Interactions  Paid
# 244  5172.0    NaN       NaN    372.0              6334.0   1.0
# 460  1546.0    NaN       NaN    146.0              1873.0   0.0
# 168  1622.0    NaN       NaN    144.0              1974.0   0.0
# 288   469.0    NaN       NaN    103.0               605.0   0.0
# 228   367.0    NaN       NaN     64.0               456.0   0.0
# ..      ...    ...       ...      ...                 ...   ...
# 495    53.0   26.0       3.0      NaN                 NaN   NaN
# 496    53.0   22.0       2.0      NaN                 NaN   NaN
# 497    93.0   18.0       1.0      NaN                 NaN   NaN
# 498    91.0   38.0       3.0      NaN                 NaN   NaN
# 499    91.0   28.0       2.0      NaN                 NaN   NaN
#
# [1000 rows x 6 columns]

# %%
concat.T
# Out:
#                      0      1     2       3      4      5      6      7    \
# like                79.0  130.0  66.0  1572.0  325.0  152.0  249.0  325.0
# share               17.0   29.0  14.0   147.0   49.0   33.0   27.0   14.0
# Category             2.0    2.0   3.0     2.0    2.0    2.0    3.0    3.0
# comment              NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# Total Interactions   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# Paid                 NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
#
#                       8      9    ...    490    491    492    493    494  \
# like                161.0  113.0  ...   79.0  105.0  128.0  185.0  125.0
# share                31.0   26.0  ...    NaN    NaN    NaN    NaN    NaN
# Category              2.0    3.0  ...    NaN    NaN    NaN    NaN    NaN
# comment               NaN    NaN  ...    1.0    1.0    0.0   17.0   10.0
# Total Interactions    NaN    NaN  ...  110.0  152.0  137.0  257.0  176.0
# ...

# %%
concat.transpose()
# Out:
#                      0      1     2       3      4      5      6      7    \
# like                79.0  130.0  66.0  1572.0  325.0  152.0  249.0  325.0
# share               17.0   29.0  14.0   147.0   49.0   33.0   27.0   14.0
# Category             2.0    2.0   3.0     2.0    2.0    2.0    3.0    3.0
# comment              NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# Total Interactions   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# Paid                 NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
#
#                       8      9    ...    490    491    492    493    494  \
# like                161.0  113.0  ...   79.0  105.0  128.0  185.0  125.0
# share                31.0   26.0  ...    NaN    NaN    NaN    NaN    NaN
# Category              2.0    3.0  ...    NaN    NaN    NaN    NaN    NaN
# comment               NaN    NaN  ...    1.0    1.0    0.0   17.0   10.0
# Total Interactions    NaN    NaN  ...  110.0  152.0  137.0  257.0  176.0
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
concat.shape
# Out:
# (1000, 6)

# %%
import numpy as np

# %%
arr = np.array(df[['Post Month','Post Weekday']].head(6))
reshaped = arr.reshape(3,4)
print(reshaped)
# Out:
# [[12  4 12  3]
#  [12  3 12  2]
#  [12  2 12  1]]

# %%
merged = pd.merge(subset1, subset2, on='like')

# %%
merged
# Out:
#       like  share  Category  comment  Total Interactions  Paid
# 0     79.0   17.0         2        4                 100   0.0
# 1     79.0   17.0         2        2                  97   1.0
# 2     79.0   17.0         2        1                  97   0.0
# 3     79.0   17.0         2        4                  99   0.0
# 4     79.0   17.0         2        5                  95   0.0
# ...    ...    ...       ...      ...                 ...   ...
# 1405  91.0   38.0         3        7                 136   0.0
# 1406  91.0   38.0         3        0                 119   NaN
# 1407  91.0   28.0         2        5                 122   1.0
# 1408  91.0   28.0         2        7                 136   0.0
# 1409  91.0   28.0         2        0                 119   NaN
#
# [1410 rows x 6 columns]
