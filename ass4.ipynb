# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('heart_disease_uci(1).csv')

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.isna().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs',
#        'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
sns.countplot(x="num", data=df, palette="bwr")
# Out:
# C:\Users\dhanashree\AppData\Local\Temp\ipykernel_15880\3891267782.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="num", data=df, palette="bwr")
# <Axes: xlabel='num', ylabel='count'>

# %%
df_numeric = df.select_dtypes(include=['float64','int64'])

# %%
sns.heatmap(df_numeric.corr(), cmap='YlGnBu', annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(data=df, x=df.age,y=df.cp, hue='num')
# Out:
# <Axes: xlabel='age', ylabel='cp'>

# %%
sns.lineplot(data=df, x=df.age, y= df.trestbps, hue='num')
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.lineplot(data=df, x=df.age, y= df.chol, hue='num')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.lineplot(data=df, x = df.oldpeak , y= df.exang, hue='num')
# Out:
# <Axes: xlabel='oldpeak', ylabel='exang'>

# %%
sns.lineplot(x=df.age, y=df.chol)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.histplot(data=df, x= df.num, hue =df.sex)
# Out:
# <Axes: xlabel='num', ylabel='Count'>

# %%
sns.histplot(data=df, x=df.cp, hue=df.sex)
# Out:
# <Axes: xlabel='cp', ylabel='Count'>

# %%
sns.histplot(data=df, x= df.cp,hue='num')
# Out:
# <Axes: xlabel='cp', ylabel='Count'>

# %%
sns.histplot(data=df,x=df.age,hue='num')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df,x=df.trestbps,hue='num')
# Out:
# <Axes: xlabel='trestbps', ylabel='Count'>

# %%
sns.lineplot(x=df.age, y=df.chol)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.countplot(x='sex', data=df, palette="mako_r")
#  plt.xlabel("Sex (0 = female, 1= male)")
#  plt.show()
# Out:
# C:\Users\dhanashree\AppData\Local\Temp\ipykernel_15880\1661529963.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=df, palette="mako_r")
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.violinplot(data=df, x='sex', y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(data=df, x='sex', y='age', jitter=True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(data=df, x='sex', y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>
# C:\Users\dhanashree\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
